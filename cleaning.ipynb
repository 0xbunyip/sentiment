# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import string
import sys

default_stdout = sys.stdout
default_stderr = sys.stderr
reload(sys)
sys.stdout = default_stdout
sys.stderr = default_stderr
sys.setdefaultencoding('utf8')

# %% [markdown]
# # Clean game data

# %%
lines = [line.rstrip('\n') for line in open('./raw/game.csv')]
lines_join = []
s = ""
for line in lines:
    s += line
    s = s.replace('\xe2\x84\xa2', '') # delete '™'
    if line[-1] == "\"" and line[-2] == "]":
        lines_join.append(s + '\n')
        s = ""
        
fatt = open('./raw/game_attribute.txt', 'r')
game_att = fatt.readlines()
fatt.close()
        
fout = open('./clean/game_p.csv', 'w')
fout.writelines(game_att[0] + '\n')
fout.writelines(lines_join)
fout.close()

# %%
game = pd.DataFrame.from_csv('./clean/game_p.csv')
print game.shape
print game.dtypes
game.head(15)
# Out:
# (15, 4)
# game_name       object
# release_date    object
# price           object
# game_tag        object
# dtype: object
#                                      game_name release_date         price  \
# ID
# 730           Counter-Strike: Global Offensive   2012-08-21    $14.99 USD
# 252950                           Rocket League   2015-07-07    $19.99 USD
# 374320                          DARK SOULS III   2016-04-11    $59.99 USD
# 363680              Battlefleet Gothic: Armada   2016-04-21    $39.99 USD
# 322330                   Don't Starve Together   2016-04-21    $10.04 USD
# 433850                  H1Z1: King of the Kill   2016-02-17    $19.99 USD
# 271590                      Grand Theft Auto V   2015-04-14    $44.99 USD
# 220200                    Kerbal Space Program   2015-04-27    $39.99 USD
# 230410                                Warframe   2013-03-25  Free to Play
# 427520                                Factorio   2016-02-25    $20.00 USD
# 346110                   ARK: Survival Evolved   2015-06-02    $29.99 USD
# 570                                     Dota 2   2013-07-09  Free To Play
# 413150                          Stardew Valley   2016-02-26    $14.99 USD
# 411370  Melty Blood Actress Again Current Code   2016-04-19    $19.99 USD
# 440                            Team Fortress 2   2007-10-10  Free to Play
#
#                                                  game_tag
# ID
# 730     ['FPS', 'Multiplayer', 'Shooter', 'Action', 'T...
# 252950  ['Racing', 'Multiplayer', 'Soccer', 'Sports', ...
# 374320  ['Dark Fantasy', 'Difficult', 'Atmospheric', '...
# 363680  ['Strategy', 'Warhammer 40K', 'Space', 'RTS', ...
# 322330  ['Survival', 'Multiplayer', 'Co-op', 'Adventur...
# 433850  ['Early Access', 'Massively Multiplayer', 'Sur...
# 271590  ['Open World', 'Action', 'Multiplayer', 'First...
# 220200  ['Space', 'Simulation', 'Sandbox', 'Physics', ...
# 230410  ['Free to Play', 'Action', 'Co-op', 'Third-Per...
# 427520  ['Early Access', 'Base-Building', 'Resource Ma...
# 346110  ['Early Access', 'Survival', 'Dinosaurs', 'Ope...
# 570     ['Free to Play', 'MOBA', 'Strategy', 'Multipla...
# 413150  ['RPG', 'Simulation', 'Agriculture', 'Pixel Gr...
# 411370  ['Action', 'Anime', 'Fighting', '2D Fighter', ...
# 440     ['Free to Play', 'Multiplayer', 'FPS', 'Action...

# %% [markdown]
# # Clean review data

# %%
reviews_df = pd.DataFrame.from_csv('./raw/review.csv')
reviews_df.polarity = reviews_df.polarity.astype(int)
reviews_df.hour_of_gameplay = reviews_df.hour_of_gameplay.str.replace(',', '').astype(float)
reviews_df.head()
# Out:
#      hour_of_gameplay                                     content_review  \
# ID
# 730             312.4  Every team consists of 5 people:1.You2.Russian...
# 730            1117.5  Grades, ruined.Social life, ruined.Relationshi...
# 730             546.7  CS:GO is like Roulette, funny until it gets ru...
# 730             578.5  Here's what you learn and get with Counter-Str...
# 730             178.0  Over 15 maps in casual mode...You will only pl...
#
#      helpful_vote  total_vote  funny_vote  number_comment  polarity
# ID
# 730         12407       13529       15281             234         1
# 730          2122        2295        2771              38         1
# 730          3340        3657        4058              34         1
# 730          3184        3521        4235              69         1
# 730          1406        1553        1051              48         1

# %% [markdown]
# ### Split dataset into train/validate/test set

# %%
def get_split_df(reviews_df, num_train_reviews, num_val_reviews, num_test_reviews):
    num_reviews = num_train_reviews + num_val_reviews + num_test_reviews
    game_ids = reviews_df.index.unique()

    train_reviews_df = pd.DataFrame()
    val_reviews_df = pd.DataFrame()
    test_reviews_df = pd.DataFrame()
    for i in game_ids:
        game_reviews_df = reviews_df[reviews_df.index == i]
        small_reviews_df = game_reviews_df.sample(min(num_reviews, len(game_reviews_df)))
        reviews_frac = len(small_reviews_df) / float(num_reviews)

        
        train_reviews_df = pd.concat([train_reviews_df, small_reviews_df[ : int(num_train_reviews * reviews_frac)]])
        val_reviews_df = pd.concat([val_reviews_df, small_reviews_df[int(num_train_reviews * reviews_frac) : int((num_train_reviews + num_val_reviews) * reviews_frac)]])
        test_reviews_df = pd.concat([test_reviews_df, small_reviews_df[int((num_train_reviews + num_val_reviews) * reviews_frac) : ]])
    return train_reviews_df, val_reviews_df, test_reviews_df

# %%
num_train_reviews = 1000 # per game
num_val_reviews = 200 # per game
num_test_reviews = 500 # per game
    
train_reviews_df, val_reviews_df, test_reviews_df = get_split_df(reviews_df, num_train_reviews, num_val_reviews, num_test_reviews)
train_reviews_df.to_csv('./clean/train_reviews.csv')
val_reviews_df.to_csv('./clean/val_reviews.csv')
test_reviews_df.to_csv('./clean/test_reviews.csv')

# %%
tmp_df = pd.DataFrame.from_csv('./clean/train_reviews.csv')
tmp_df.describe()
# Out:
#        hour_of_gameplay  helpful_vote   total_vote    funny_vote  \
# count      59129.000000  59129.000000  59129.00000  59129.000000
# mean         584.975822    519.694465    617.25441    245.658087
# std         1212.945605   1149.474933   1364.55254    791.041344
# min            0.100000      0.000000      1.00000      0.000000
# 25%           33.300000      1.000000      2.00000      0.000000
# 50%          115.400000     11.000000     21.00000      1.000000
# 75%          604.300000    514.000000    602.00000     80.000000
# max        14430.400000  12407.000000  14475.00000  15281.000000
#
#        number_comment      polarity
# count     59129.00000  59129.000000
# mean         15.79839      0.624888
# std          39.24428      0.484156
# min           0.00000      0.000000
# 25%           0.00000      0.000000
# 50%           1.00000      1.000000
# 75%          14.00000      1.000000
# max         430.00000      1.000000

# %%
review = pd.DataFrame.from_csv('./clean/review_small_p.csv', encoding='utf-8')
review.polarity = review.polarity.astype(int)
review.hour_of_gameplay = review.hour_of_gameplay.str.replace(',', '').astype(float)
#review.content_review = review.content_review.astype('str')
review.content_review.apply(str)

print review.dtypes
print len(review)
#review.describe()
review.head(20)
# Out:
# hour_of_gameplay    float64
# content_review       object
# helpful_vote          int64
# total_vote            int64
# funny_vote            int64
# number_comment        int64
# polarity              int64
# dtype: object
# 100
#      hour_of_gameplay                                     content_review  \
# ID
# 730             312.4  Every team consists of 5 people:1.You2.Russian...
# 730            1117.5  Grades, ruined.Social life, ruined.Relationshi...
# 730             546.7  CS:GO is like Roulette, funny until it gets ru...
# 730             578.5  Here's what you learn and get with Counter-Str...
# 730             178.0  Over 15 maps in casual mode...You will only pl...
# 730            1595.7  Start playing at 6:00Play for five minutesLook...
# 730            3684.9  You can set the water on fire.You can survive ...
# 730            1053.7  1.Plays 100 games to get exp to level 32. wait...
# 730            1234.6  Kill someone with a P90 - "You're a fuc**** no...
# 730             326.8  I spent 400 bucks for nothing but bluesI still...
# 730             337.0  You play this game.You're apparently either a ...
# 730             944.3  -Opens game-Buys cases-400 blues later-Searchs...
# 730            3617.4  Counter-Strike is one of the most popular fran...
# 730            1608.7  If your looking for a review on this game you'...
# 730            1219.7  Beautiful game. First bullet accuracy of rifle...
# 730             845.8  Don't Pay Hundreds Of Bucks To Schools To Teac...
# 730             160.3  Keep Low Move FastKill First Die LastOne ShotO...
# 730             317.1  *10 yr old teammate shoots me in the leg on pu...
# 730            1238.8  CS:GO in a nutshell>Get your rank after 10 gam...
# 730             677.0  Counter Strike Global Offensive is essentially...
#
#      helpful_vote  total_vote  funny_vote  number_comment  polarity
# ID
# 730         12407       13529       15281             234         1
# 730          2122        2295        2771              38         1
# 730          3340        3657        4058              34         1
# 730          3184        3521        4235              69         1
# 730          1406        1553        1051              48         1
# 730           707         765         728              16         1
# 730          1133        1254        1195              54         1
# 730           687         763         587              33         1
# 730           555         611         617              80         1
# 730           447         500         391              73         1
# 730           474         542         508              26         1
# 730           298         331         269              16         1
# 730           376         430          60              29         1
# 730           742         897         742              35         1
# 730           233         259         204              27         1
# 730           280         324         279              12         1
# 730           749         928         513              19         1
# 730           139         145         126              26         1
# 730           333         401         288              17         1
# 730           132         158         122              16         1

# %%
review.content_review.map(lambda x: len(x)).mean()
# Out:
# 514.88

# %%
review.content_review
# Out:
# ID
# 730    Every team consists of 5 people:1.You2.Russian...
# 730    Grades, ruined.Social life, ruined.Relationshi...
# 730    CS:GO is like Roulette, funny until it gets ru...
# 730    Here's what you learn and get with Counter-Str...
# 730    Over 15 maps in casual mode...You will only pl...
# 730    Start playing at 6:00Play for five minutesLook...
# 730    You can set the water on fire.You can survive ...
# 730    1.Plays 100 games to get exp to level 32. wait...
# 730    Kill someone with a P90 - "You're a fuc**** no...
# 730    I spent 400 bucks for nothing but bluesI still...
# 730    You play this game.You're apparently either a ...
# 730    -Opens game-Buys cases-400 blues later-Searchs...
# 730    Counter-Strike is one of the most popular fran...
# 730    If your looking for a review on this game you'...
# 730    Beautiful game. First bullet accuracy of rifle...
# 730    Don't Pay Hundreds Of Bucks To Schools To Teac...
# 730    Keep Low Move FastKill First Die LastOne ShotO...
# 730    *10 yr old teammate shoots me in the leg on pu...
# 730    CS:GO in a nutshell>Get your rank after 10 gam...
# 730    Counter Strike Global Offensive is essentially...
# 730                                I want to kill myself
# 730    Counter strike is a lovely game with a lovely ...
# 730    I launched this game and witnessed history as ...
# 730    Love it or hate it. I do both. Story: Police v...
# 730    Have you ever been to Russia? No? Would you lo...
# 730    Apart from being primarily a game, made for en...
# 730    Competitive in a nutshell:-Atleast 1 Russian-4...
# 730    I spent 400 bucks for nothing but bluesI still...
# 730    This Game Wasted The Following1 - MyTime.2 - M...
# 730    >be at school>have headphones in>headphones co...
#                              ...
# 730    Now that i played this game for quite a while,...
# 730    Csgo.. man where should i start?I've been play...
# 730    I may have not a lot of hours in general, but ...
# 730    I've had this game since Operation Bloodhound ...
# 730    I don't have much to say but I want to recomme...
# 730    See, we can't make fun of silvers anymore beca...
# 730                  Casino Simulator: Global Oppression
# 730    Legend say's Vladimir Putin has a Kremlin fund...
# 730    Counter-Strike is like roulette. It's fun, unt...
# 730    Pretty cool game unless you have a bunch of no...
# 730    Well hi and thanks for stopping by.After over ...
# 730    The only game that I have ever seen that peopl...
# 730    If you have a russian on your team you should ...
# 730     So many Russians it gave me anal bleeding, 10/10
# 730                                               Rush B
# 730    At first I was like "Hey, it's not as salty as...
# 730     Counter-Strike: Global Offensive After 1k of ...
# 730       I hate this garbage game I'm gonna kill myself
# 730    i ♥♥♥♥ing want to kill myself everytime i play...
# 730    This game is FANTASTIC!!First day playing csgo...
# 730                                 R8 R8 啪啪两发，你要不死，我就自杀
# 730    Ever wanted to hear 20 year old men and 12 yea...
# 730    This game is pretty fun. I like how you can ge...
# 730    They say money can't buy happiness...True... U...
# 730    This game won't teach you group tactics... Thi...
# 730    So how do I start this review...First of all I...
# 730    counter-striker：Russian-Chinese-kids-hackersco...
# 730    Learn professional russian in just 1 month for...
# 730    One of the very few games people have 500+ hou...
# 730                         ♥♥♥♥♥♥ic shooting experience
# Name: content_review, dtype: object

# %%
import string
printable = set(string.printable)
b = filter(lambda x: x in printable, a)
c = b.replace(',', ' ').replace('.', ' ').lower()
print a
print b
print c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a3d37830097b> in <module>()
#       1 import string
#       2 printable = set(string.printable)
# ----> 3 b = filter(lambda x: x in printable, a)
#       4 c = b.replace(',', ' ').replace('.', ' ').lower()
#       5 print a
#
# NameError: name 'a' is not defined

# %%
import re
b = re.sub(r'[^\x00-\x7F]+',' ', a)
b
